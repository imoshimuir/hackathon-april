# %%
import numpy as np 
import pandas as pd 
import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_io as tfio
import os, random
import shutil
from pydub import AudioSegment
import glob
from pathlib import Path
from IPython.display import display, Audio
import soundfile as sf

# %%
# Specify the path where you want to save the model weights
weights_path = 'weights/my_model_weights.h5'

# %%
ROOT = "/home/gridsan/clast/hackathon-april"
train_metadata = pd.read_csv(os.path.join(ROOT, 'metadata.csv'))[['primary_label', 'filename']]
train_metadata['filepath'] = 'data/Binary_Drone_Audio/' + train_metadata['filename']
classes = set(random.sample(train_metadata['primary_label'].unique().tolist(), 2))

# %%
# Rebuild the model architecture
model_reloaded = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024), dtype=tf.float32, name='input_embedding'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(len(classes))  # Make sure `classes` is defined or replace `len(classes)` with the actual number
], name='my_reloaded_model')

# Load the weights
model_reloaded.load_weights(weights_path)

# If your model requires compiling to make predictions, compile the model
model_reloaded.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                       optimizer="adam",
                       metrics=['accuracy'])

# Now the model is ready to be used for predictions or evaluation

# %%
# @tf.function
# def load_wav_16k_mono(filename):
#     """Load a WAV file, convert it to a float tensor, and resample to 16 kHz single-channel audio."""
#     file_contents = tf.io.read_file(filename)
#     wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
#     wav = tf.squeeze(wav, axis=-1)
#     if sample_rate != 16000:
#         wav = tfio.audio.resample(wav, rate_in=tf.cast(sample_rate, tf.int64), rate_out=16000)
#     return wav


# def create_segments_for_directory(directory, segment_duration=0.975, sr=16000):
#     """Create fixed-length segments for all WAV files in a directory."""
#     file_paths = glob.glob(directory + '/*.wav')  # Adjust pattern if necessary
#     all_segments = []
#     segment_samples = int(segment_duration * sr)  # Number of samples per segment

#     for file_path in file_paths:
#         audio = load_wav_16k_mono(file_path)
#         audio_length = tf.shape(audio)[0]
#         num_segments = audio_length // segment_samples

#         for i in range(num_segments):
#             start_sample = i * segment_samples
#             end_sample = start_sample + segment_samples
#             segment = audio[start_sample:end_sample]
#             start_time = tf.cast(start_sample, tf.float32) / sr  # Convert sample index to time in seconds
#             all_segments.append((file_path, start_time, segment))

#     return all_segments

# def load_wav_segment(file_path, start, segment):
#     """Prepare a segment for TensorFlow dataset format, with metadata."""
#     # Optionally reshape or process segment if necessary
#     segment_tensor = tf.reshape(segment, [1, -1])  # Ensure it has a batch dimension
#     return segment_tensor, file_path, start

# def generate_dataset(directory):
#     segments = create_segments_for_directory(directory)
#     # Convert list to TensorFlow dataset
#     segments_ds = tf.data.Dataset.from_generator(
#         lambda: segments,
#         output_types=(tf.string, tf.float32, tf.float32),
#         output_shapes=((), (), (None,))
#     )
#     # Map loading function to dataset
#     segments_ds = segments_ds.map(lambda fp, st, sg: load_wav_segment(fp, st, sg))
#     return segments_ds

# %%
@tf.function
def load_wav_16k_mono(filename):
    """Load a WAV file, convert it to a float tensor, and resample to 16 kHz single-channel audio."""
    file_contents = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(file_contents, desired_channels=1)
    wav = tf.squeeze(wav, axis=-1)
    if sample_rate != 16000:
        wav = tfio.audio.resample(wav, rate_in=tf.cast(sample_rate, tf.int64), rate_out=16000)
    return wav

def create_segments_for_directory(directory, sr=16000, segment_samples=1024):
    """Create fixed-length segments for all WAV files in a directory, each segment being 1024 samples long."""
    file_paths = glob.glob(directory + '/*.wav')  # Adjust pattern if necessary
    all_segments = []

    for file_path in file_paths:
        audio = load_wav_16k_mono(file_path)
        audio_length = tf.shape(audio)[0]
        num_segments = audio_length // segment_samples

        for i in range(num_segments):
            start_sample = i * segment_samples
            end_sample = start_sample + segment_samples
            segment = audio[start_sample:end_sample]
            start_time = tf.cast(start_sample, tf.float32) / sr  # Convert sample index to time in seconds
            all_segments.append((file_path, start_time, segment))

    return all_segments

# %%
def load_wav_segment(file_path, start, segment):
    """Prepare a segment for TensorFlow dataset format, with metadata."""
    # Optionally reshape or process segment if necessary
    segment_tensor = tf.reshape(segment, [1, -1])  # Ensure it has a batch dimension
    return segment_tensor, file_path, start

def generate_dataset(directory):
    segments = create_segments_for_directory(directory)
    # Convert list to TensorFlow dataset
    segments_ds = tf.data.Dataset.from_generator(
        lambda: segments,
        output_types=(tf.string, tf.float32, tf.float32),
        output_shapes=((), (), (None,))
    )
    # Map loading function to dataset
    segments_ds = segments_ds.map(lambda fp, st, sg: load_wav_segment(fp, st, sg))
    return segments_ds

# %%
# Example usage
directory = 'data/test_data'
test_dataset = generate_dataset(directory)

# Display dataset structure
for features, file_path, start_time in test_dataset.take(1):
    print("Features shape:", features.shape)
    print("File Path:", file_path.numpy().decode('utf-8'), "Start Time:", start_time.numpy())
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:5 out of the last 5 calls to <function load_wav_16k_mono at 0x7f598e7cc700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:6 out of the last 6 calls to <function load_wav_16k_mono at 0x7f598e7cc700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample
# Features shape: (1, 1024)
# File Path: data/test_data/DRONE_018.wav Start Time: 0.0

# %%
def predict_with_metadata(model, dataset):
    """Predict using model and return predictions with metadata."""
    results = []
    for wav_tensor, file_path, start in dataset:
        print(wav_tensor, file_path, start)
        predictions = model.predict(wav_tensor)
        probabilities = tf.nn.softmax(predictions).numpy()
        predicted_classes = np.argmax(probabilities, axis=1)

        results.append((file_path.numpy().decode('utf-8'), start.numpy(), probabilities, predicted_classes))
    return results

# Example usage
predictions_with_metadata = predict_with_metadata(model_reloaded, test_dataset)
# Out:
# tf.Tensor(
# [[-7.0289667e-07  1.3009848e-06  2.9782027e-06 ...  3.4204012e-01
#    2.0183794e-01 -1.8140333e-02]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.0, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08595809  0.05264312  0.04353417 ...  0.00741842 -0.18549806
#   -0.09958941]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.064, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.10941676 -0.21260847 -0.0752945  ...  0.08607049 -0.02853771
#    0.01273412]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.128, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00688485 -0.17047666 -0.00445479 ...  0.30323622  0.14840145
#    0.20075089]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.192, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.1165347  -0.01137509  0.00801694 ... -0.04571043  0.09155435
#   -0.00108215]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.256, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.04740944  0.09855877  0.07718363 ... -0.05184377  0.01447156
#   -0.11791085]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.32, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.11955953 -0.06618082 -0.02806489 ... -0.02127185 -0.0354168
#   -0.00748292]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.384, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06023837  0.10511156  0.07778935 ... -0.18165363 -0.18468757
#   -0.25617355]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.448, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.25110316 -0.23121724 -0.26192653 ... -0.16573778 -0.06489857
#   -0.1272503 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.512, shape=(), dtype=float32)
# tf.Tensor(
# [[-2.2896425e-01  3.8110418e-04 -3.7593611e-02 ... -3.0882394e-01
#   -2.0039257e-01 -7.8952478e-05]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.576, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04954549  0.14327402  0.23171444 ... -0.09514067 -0.2468857
#   -0.23391113]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.64, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.08455203 -0.22753638 -0.15420403 ...  0.1946871   0.02632182
#   -0.10730732]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.704, shape=(), dtype=float32)
# tf.Tensor([[0.02026864 0.10231777 0.14607337 ... 0.06781798 0.13877751 0.12740597]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.768, shape=(), dtype=float32)
# tf.Tensor([[0.24640813 0.22434852 0.16389544 ... 0.07094573 0.01352834 0.06616241]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.832, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.15466014  0.01790739  0.1357889  ...  0.01595819 -0.03777295
#   -0.10836593]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.896, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.11253613 -0.09404017 -0.16319986 ... -0.15100443 -0.1832518
#   -0.08240616]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(0.96, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.17696893 -0.14694083 -0.14558047 ...  0.01644277  0.00033336
#    0.03742241]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.024, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05817632 -0.03144056 -0.10031866 ... -0.04378398  0.01118344
#    0.04200607]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.088, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0275008  -0.00170662 -0.03288155 ...  0.06732162  0.14843518
#    0.1274437 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.152, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.18243606  0.26656127  0.27687818 ...  0.00779016 -0.02756692
#   -0.03447369]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.216, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01603168 -0.10777792  0.01423924 ...  0.01908133 -0.05574512
#   -0.08754843]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.28, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.14832017 -0.11205754 -0.23535141 ...  0.09723256  0.01443571
#    0.02481815]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.344, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.13508537  0.08602587  0.0707262  ... -0.18901132 -0.1709525
#   -0.18252248]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.408, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.26445234 -0.20521957 -0.06300588 ... -0.09060486 -0.18754944
#   -0.06522858]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.472, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.08995877 -0.12791437 -0.01002253 ... -0.19296074 -0.17777552
#   -0.1713628 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.536, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.18811972  0.033081    0.04946434 ... -0.13159344  0.10919615
#    0.25151718]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.6, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08356224  0.12753734 -0.01322874 ... -0.11322656 -0.05109092
#   -0.18960905]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.664, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05248579  0.18704227  0.08658211 ...  0.04195379  0.09017825
#   -0.00917303]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.728, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00504133  0.00929422 -0.05516228 ...  0.10669286  0.20012894
#    0.35421282]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.792, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.29398125  0.19477405  0.130648   ... -0.01941558 -0.09747365
#   -0.04788046]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.856, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.11750985 -0.04712996 -0.07063647 ...  0.25201723  0.04601076
#    0.05437723]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.92, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08545993  0.01250621 -0.0515502  ...  0.01534407 -0.0665007
#    0.05041393]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(1.984, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06608621 -0.08375758 -0.04774146 ... -0.00129651  0.27436256
#    0.21823904]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.048, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05514651 -0.02570254 -0.10094345 ... -0.04771726  0.08995719
#    0.0253514 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.112, shape=(), dtype=float32)
# tf.Tensor([[0.07831775 0.08892382 0.0180115  ... 0.15955244 0.00134671 0.06681644]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.176, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.14895271 -0.04006393  0.00235581 ... -0.03637901 -0.02069525
#   -0.05650305]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.24, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03889211 -0.03830443  0.02514617 ... -0.1498741  -0.25722635
#   -0.1527666 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.304, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.07176775 -0.19752812 -0.22927228 ... -0.01751388 -0.00046988
#    0.18911856]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.368, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.2784967   0.1966786   0.23694864 ... -0.19373944 -0.11053881
#   -0.18393704]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.432, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.2328091  -0.3029998  -0.10315083 ...  0.04243112 -0.00032952
#    0.05057579]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.496, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01528226 -0.08779983 -0.1118002  ...  0.10539602  0.00786853
#   -0.14044905]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.56, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04132298 -0.19801348 -0.18719596 ... -0.10033335 -0.08481043
#   -0.18837826]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.624, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.17113009 -0.24492201 -0.10874104 ... -0.09108493 -0.03600794
#    0.00937559]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.688, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05327909  0.07658404  0.07127012 ...  0.02783444 -0.05074982
#   -0.09752379]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.752, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.1131398  -0.07147659 -0.01399276 ...  0.13386922  0.2076396
#    0.29249647]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.816, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.20972963  0.18541318  0.09507953 ...  0.09187437  0.04491605
#   -0.00325932]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.88, shape=(), dtype=float32)
# tf.Tensor([[0.10306965 0.10833684 0.12231031 ... 0.1030854  0.07679486 0.06267734]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(2.944, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01641095 -0.03392782  0.03903839 ...  0.04122438 -0.04441176
#   -0.04427296]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.008, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06879376 -0.0296174  -0.13633908 ... -0.04978201 -0.03005787
#   -0.09704989]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.072, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02347102 -0.07499707 -0.08178627 ... -0.02306088 -0.00865511
#   -0.06566314]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.136, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.04263966 -0.00763409 -0.05412216 ... -0.04419732 -0.04693406
#   -0.1102712 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.2, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04509851 -0.1076735  -0.06145513 ...  0.09968619  0.00052095
#   -0.07177862]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.264, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00272593  0.00677529 -0.01725355 ... -0.03553017 -0.02407122
#    0.03195524]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.328, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.06679104 -0.07194753 -0.04393531 ... -0.01381892  0.01999899
#   -0.01037693]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.392, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03015848  0.01875938 -0.03261807 ... -0.12142781 -0.04043217
#   -0.00296069]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.456, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02199702  0.03288213  0.07360011 ...  0.07919175  0.06376632
#    0.0120234 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.52, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.04943395 -0.07557844  0.04117509 ... -0.00218868 -0.02271041
#   -0.05846125]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.584, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04864804 -0.05457355 -0.07477694 ... -0.01478404  0.00246339
#    0.03030904]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.648, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04520098 -0.06404831 -0.02008489 ...  0.09962901  0.12640807
#    0.16951232]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.712, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.22398949  0.24762918  0.268511   ... -0.07268482 -0.05016701
#   -0.07228745]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.776, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.15788291 -0.13844138 -0.02806049 ... -0.13938323 -0.15317279
#    0.05066689]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.84, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.10239765 -0.11944924 -0.14184353 ... -0.02363016 -0.08140956
#   -0.10142957]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.904, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00728171 -0.0300128   0.00876326 ... -0.0334386  -0.02509925
#   -0.00871842]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(3.968, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.02830738  0.03547893  0.02650153 ... -0.14617512 -0.06074497
#   -0.04833561]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.032, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05974662 -0.05338592 -0.08267419 ... -0.16233549 -0.19136068
#   -0.13147527]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.096, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04026886 -0.10292777 -0.16021168 ... -0.29993638 -0.40949598
#   -0.21589872]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.16, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.24222067 -0.24036673 -0.0591091  ... -0.06186756 -0.08493055
#   -0.14431553]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.224, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.11372893 -0.12246563 -0.04927293 ... -0.11584473 -0.09071883
#   -0.01537165]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.288, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03512268 -0.04625867 -0.09220427 ... -0.06880072 -0.00452934
#   -0.14383578]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.352, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.12246081 -0.05247203 -0.06078496 ...  0.10769597  0.06272212
#   -0.00512369]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.416, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.08227135 -0.01501634 -0.0568731  ... -0.0795696  -0.10049471
#   -0.07439347]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.48, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.17448455  0.05467317  0.10728546 ...  0.0447385  -0.13428947
#   -0.03608721]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.544, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.13220707 -0.10919777 -0.01003384 ... -0.04115991  0.00151949
#   -0.06102208]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.608, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00079715  0.05565169  0.00159697 ... -0.04122197  0.00099195
#   -0.0246882 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.672, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.07115962  0.00224007  0.05402516 ... -0.10989428 -0.17778312
#   -0.06340278]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.736, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.1320873  -0.08555935  0.03763836 ...  0.02484632 -0.04288255
#   -0.03709107]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.8, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03851672 -0.00121206  0.08066259 ...  0.1396533   0.12543406
#    0.14532605]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.864, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.09701208  0.0940467   0.10872012 ... -0.08313327 -0.05108725
#    0.00503819]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.928, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06978996  0.02108015  0.0387348  ... -0.03308294 -0.02148483
#    0.04611787]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(4.992, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00066959 -0.04909211 -0.08635097 ... -0.05387235  0.0279486
#   -0.00250785]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.056, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00588669  0.05305052 -0.04629149 ... -0.01313549 -0.00409578
#    0.04045453]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.12, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02116073 -0.02678067 -0.05165795 ...  0.01728402  0.00598349
#   -0.06727816]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.184, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.10843068  0.02487972 -0.0861238  ... -0.14429104 -0.20095804
#   -0.17637406]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.248, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.1734647  -0.15186265 -0.04845089 ...  0.10517891  0.18748057
#    0.05404662]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.312, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06204958  0.00674235 -0.02043041 ...  0.20353521  0.09459446
#    0.01989376]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.376, shape=(), dtype=float32)
# tf.Tensor([[0.04936847 0.12913355 0.11415404 ... 0.11082562 0.42531878 0.20266543]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.44, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.25290573  0.2552348   0.16669704 ... -0.22233465 -0.17397293
#   -0.02006667]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.504, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.142155   -0.11736683 -0.11090492 ...  0.02278894  0.026236
#    0.00182972]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.568, shape=(), dtype=float32)
# tf.Tensor([[0.0109355  0.08449746 0.05307444 ... 0.04323691 0.00082882 0.11905529]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.632, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.12350242  0.22542882  0.16476202 ... -0.09531102 -0.04158711
#   -0.16913395]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.696, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0972861   0.01938924 -0.00546295 ...  0.00194789  0.00625
#   -0.04573451]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.76, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03270871  0.04243016  0.09973596 ... -0.09996691 -0.11572025
#   -0.08514626]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.824, shape=(), dtype=float32)
# tf.Tensor([[0.06409542 0.08687986 0.06229211 ... 0.0194851  0.03694879 0.10784831]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.888, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00653005 -0.0588729  -0.06139347 ... -0.06343188 -0.07686052
#   -0.01492441]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(5.952, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.09616542 -0.15618159 -0.15896662 ... -0.01608169  0.0740149
#    0.04268317]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.016, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05664093 -0.01828412 -0.04014811 ... -0.08383843 -0.00572981
#    0.0136348 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.08, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05157814  0.06577848  0.05825606 ... -0.10447016 -0.05588418
#   -0.07535338]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.144, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.111927   -0.02940148  0.08519122 ... -0.08971025 -0.06974658
#   -0.03977839]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.208, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00453943 -0.03548389 -0.05612534 ... -0.08150905 -0.0693356
#   -0.01748524]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.272, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04752435 -0.07583617 -0.0633781  ...  0.21548596  0.15023042
#    0.09158932]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.336, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.1731985   0.08906613  0.12002286 ... -0.03008882 -0.02593206
#   -0.01834709]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.4, shape=(), dtype=float32)
# tf.Tensor([[0.01146448 0.08783204 0.03550792 ... 0.00181816 0.01295527 0.05316712]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.464, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.13816741  0.08926111  0.02528547 ... -0.02257442 -0.02905538
#   -0.0133594 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.528, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00457975 -0.01163269  0.07649607 ... -0.15567113 -0.16658205
#   -0.1563409 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.592, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.09037472 -0.10340944 -0.09341864 ...  0.18415262  0.24288365
#    0.1168949 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.656, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0935375   0.14919607  0.08346864 ...  0.04836407  0.02506733
#   -0.08310759]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.72, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00521551  0.04899076  0.04186444 ...  0.01381163 -0.01971985
#   -0.0016467 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.784, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03241443  0.02679894 -0.1139276  ... -0.03745497  0.00221281
#    0.0286421 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.848, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01350446 -0.03221137  0.06249703 ...  0.07485519 -0.01991278
#   -0.07181971]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.912, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05088216 -0.04869401 -0.05219897 ...  0.07063961  0.00294135
#   -0.03085357]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(6.976, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02317835 -0.01953399 -0.01618722 ... -0.07027216 -0.20309961
#   -0.0608089 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.04, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04262804 -0.11695565  0.00162853 ... -0.00174475  0.09650628
#    0.12449433]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.104, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.14731117  0.1307804  -0.08458686 ...  0.0965167   0.04431277
#    0.15369906]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.168, shape=(), dtype=float32)
# tf.Tensor([[0.14502004 0.00893533 0.04868762 ... 0.05338822 0.07934166 0.08258288]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.232, shape=(), dtype=float32)
# tf.Tensor([[0.05753635 0.01425765 0.00745236 ... 0.10639728 0.01593175 0.14100027]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.296, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01874759  0.06989478  0.05871173 ... -0.0102784   0.07495811
#    0.0745433 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.36, shape=(), dtype=float32)
# tf.Tensor([[0.05438511 0.00968947 0.00864195 ... 0.22113481 0.20364387 0.10277686]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.424, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00496244 -0.04784309 -0.07400326 ...  0.08568875  0.23043379
#    0.34542662]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.488, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.37642413  0.21415003  0.03172386 ... -0.00985181 -0.05570086
#   -0.0505668 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.552, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03810814 -0.05593443 -0.09613912 ...  0.27164045  0.17056791
#   -0.02341359]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.616, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.02940748 -0.01628871 -0.05772346 ... -0.0350375  -0.03877671
#   -0.00862316]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.68, shape=(), dtype=float32)
# tf.Tensor(
# [[-3.1812832e-02  9.0202084e-06 -8.0311783e-02 ... -1.1862406e-01
#   -6.3117817e-02 -6.5430693e-02]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.744, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03752648  0.07719588  0.09805017 ...  0.21296144  0.15595667
#    0.10815595]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.808, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08088463  0.00930775  0.05347731 ... -0.04584641 -0.0661868
#   -0.06554087]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.872, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00581083 -0.0255795  -0.03745732 ...  0.11279216  0.08585215
#    0.11013184]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(7.936, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0093892  -0.00310083 -0.04522628 ... -0.07848254  0.00782083
#   -0.08550127]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.0, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0670643   0.07104822  0.0851352  ... -0.03451082  0.09433378
#    0.0406363 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.064, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.04960059  0.03925318  0.06106439 ... -0.07493117  0.03022747
#   -0.02897534]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.128, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05799144 -0.02685104 -0.02349688 ... -0.05425087 -0.00944118
#   -0.07031751]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.192, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00612815 -0.11601588 -0.01203223 ...  0.1953557   0.09436959
#    0.10046268]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.256, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08272214 -0.0698682  -0.04292042 ... -0.08496422 -0.0517923
#   -0.02512157]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.32, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.08135436 -0.03708624 -0.01646697 ...  0.01957196  0.05040202
#   -0.02832265]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.384, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0118749  -0.05245938 -0.09321629 ...  0.2029304   0.13411316
#    0.21953174]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.448, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0904694   0.11589767  0.16491063 ...  0.0609777   0.03625356
#   -0.00404162]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.512, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04049108 -0.08483288 -0.01050886 ...  0.06877524  0.07028911
#    0.01869325]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.576, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.07953167  0.01702673  0.11950748 ... -0.10209726 -0.04771768
#   -0.0261826 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.64, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.07566454 -0.06699171 -0.11316661 ... -0.07455822  0.08030739
#   -0.06640065]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.704, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01800369  0.08434299 -0.01995423 ... -0.07593908  0.01643979
#   -0.01367607]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.768, shape=(), dtype=float32)
# tf.Tensor([[0.02712413 0.0860242  0.10948516 ... 0.09477107 0.0801177  0.09548926]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.832, shape=(), dtype=float32)
# tf.Tensor([[0.07078593 0.03313281 0.07542431 ... 0.09085879 0.02117144 0.03342985]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.896, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05317747 -0.05024703  0.0437445  ...  0.08186861  0.12435263
#    0.10382772]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(8.96, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.22584361  0.14227924  0.07500737 ... -0.02793287 -0.02799316
#   -0.04300748]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.024, shape=(), dtype=float32)
# tf.Tensor([[0.00529282 0.06408425 0.00903221 ... 0.12323074 0.25497085 0.27473816]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.088, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.16772632  0.17352581  0.11815032 ... -0.0695385  -0.04778647
#   -0.02901591]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.152, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01219966  0.01692494  0.03553067 ... -0.04284763 -0.02574343
#   -0.03891889]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.216, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06056626  0.00423489 -0.02187177 ...  0.19908485  0.23996161
#    0.18555018]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.28, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.02950587  0.09969012  0.09145613 ... -0.03241789 -0.01612147
#    0.02087912]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.344, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03803884 -0.01971168 -0.01584645 ...  0.0114284   0.02059711
#    0.00737486]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.408, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.08234538  0.05664321  0.13252616 ... -0.04569713  0.01811549
#    0.06651102]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.472, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.07400698  0.01506083  0.01899172 ...  0.06758208 -0.00159548
#    0.03681431]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.536, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03300585  0.02884915  0.06939261 ... -0.04259683 -0.13118884
#   -0.11446811]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.6, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.18494537 -0.05028132 -0.06237935 ... -0.08990863 -0.10097741
#   -0.11203492]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.664, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.06244677  0.03521524 -0.02605434 ... -0.03398526 -0.04268355
#    0.10333049]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.728, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05776934 -0.01320409 -0.07103119 ...  0.05322905 -0.03770935
#    0.02689107]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.792, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00193113  0.0211846   0.0564034  ...  0.02206536  0.0373241
#   -0.03396662]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.856, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01803116 -0.03969794  0.01102713 ... -0.08840343 -0.03986037
#   -0.00049176]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_018.wav', shape=(), dtype=string) tf.Tensor(9.92, shape=(), dtype=float32)
# tf.Tensor(
# [[-5.42967937e-09  1.51833497e-08  1.21835955e-08 ...  2.86731962e-03
#    1.58683420e-03  7.14632915e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.0, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00045896  0.00063122 -0.00013214 ... -0.00282107 -0.00161635
#    0.00014767]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.064, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00031287 -0.0018174  -0.00194229 ...  0.00143543  0.00072756
#   -0.00059252]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.128, shape=(), dtype=float32)
# tf.Tensor(
# [[-4.1215430e-04  6.6357017e-05 -1.4427435e-04 ... -7.0641981e-04
#    3.8677466e-04  1.2801109e-03]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.192, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00015636 -0.00143495 -0.00106308 ... -0.00521825 -0.00282699
#   -0.00065638]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.256, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00225672 -0.00534062 -0.00470619 ... -0.00119387 -0.00108825
#    0.00070015]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.32, shape=(), dtype=float32)
# tf.Tensor(
# [[ 6.2297986e-05 -2.5477624e-03 -2.9400354e-03 ...  3.6571117e-04
#   -1.3196638e-03 -2.9228292e-03]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.384, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00246164 -0.00025927 -0.00052586 ... -0.00051456  0.00039907
#    0.00181918]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.448, shape=(), dtype=float32)
# tf.Tensor(
# [[ 9.7776193e-04 -3.4683934e-04 -2.3212910e-05 ... -1.1053385e-03
#   -5.6948262e-04 -1.3125311e-03]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.512, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00224996 -0.001671   -0.00114337 ...  0.00017398 -0.00017581
#   -0.00067435]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.576, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00017508  0.00076237  0.00076646 ... -0.00219614 -0.00249667
#   -0.0023224 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.64, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00197003 -0.00213688 -0.0030273  ... -0.00257348 -0.00215275
#   -0.00207539]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.704, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00213732 -0.00186759 -0.00157235 ... -0.00175282 -0.00279906
#   -0.00209114]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.768, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00104683 -0.0016584  -0.00298102 ... -0.00147467  0.00142247
#    0.00224043]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.832, shape=(), dtype=float32)
# tf.Tensor(
# [[-2.8122461e-04 -1.6420612e-03 -3.8670396e-04 ...  3.3024004e-05
#   -9.1169716e-04 -1.1120487e-03]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.896, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0006951  -0.00028783 -0.00095454 ... -0.00060031 -0.00177708
#   -0.00177985]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(0.96, shape=(), dtype=float32)
# tf.Tensor(
# [[-9.7717822e-04 -2.6054615e-05 -3.0156018e-04 ... -1.2514147e-03
#   -1.1323200e-03  1.1132380e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.024, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00077657  0.00016353 -0.00035943 ...  0.00757037  0.00630541
#    0.00311212]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.088, shape=(), dtype=float32)
# tf.Tensor([[0.001426   0.00183642 0.00200591 ... 0.00354893 0.00250286 0.00421573]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.152, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00394175  0.00102037  0.00050336 ... -0.00334367 -0.00335056
#   -0.00437564]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.216, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00462792 -0.00391766 -0.00309871 ... -0.00047266 -0.00016388
#    0.00153925]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.28, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00318617  0.00277749  0.00185822 ... -0.00027822 -0.00023954
#   -0.00015859]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.344, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00105869 -0.00179634 -0.0017313  ... -0.00011245 -0.00037408
#   -0.00078579]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.408, shape=(), dtype=float32)
# tf.Tensor(
# [[-1.3891233e-03 -7.4231089e-04  3.1901128e-04 ... -2.1913893e-06
#   -3.9278928e-04 -2.0386226e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.472, shape=(), dtype=float32)
# tf.Tensor(
# [[-4.0734390e-05  1.7053540e-05 -6.1584200e-04 ...  3.7235906e-04
#    3.3654764e-04 -4.2737421e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.536, shape=(), dtype=float32)
# tf.Tensor(
# [[-6.1610207e-04 -5.0804269e-04 -5.8037596e-05 ...  1.3281733e-03
#    1.7985459e-03  9.4336586e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.6, shape=(), dtype=float32)
# tf.Tensor(
# [[-1.97171976e-04 -3.45098262e-04 -1.03052655e-04 ...  4.66313686e-05
#    7.10656052e-04  6.14058110e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.664, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00072474 -0.00052759  0.00084347 ... -0.00066111 -0.00038364
#   -0.00053958]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.728, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00074812 -0.00079362 -0.00104249 ...  0.0002312   0.00040249
#   -0.00024848]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.792, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00083667 -0.00050903  0.00096897 ...  0.00042449 -0.00034266
#   -0.0004861 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.856, shape=(), dtype=float32)
# tf.Tensor(
# [[ 7.5540702e-05  2.6881235e-04 -8.4224960e-04 ... -8.7117578e-06
#   -8.1425576e-05 -1.1374681e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.92, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00014814  0.00030351 -0.00031894 ... -0.00099783 -0.00072149
#   -0.00057916]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(1.984, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00079948 -0.00120492 -0.0015565  ...  0.00107782  0.00162841
#    0.00183251]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.048, shape=(), dtype=float32)
# tf.Tensor(
# [[ 1.4058189e-03  6.2767847e-04  6.3439715e-04 ... -7.8039477e-05
#   -3.8590777e-04 -5.4526009e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.112, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00062635 -0.00105205 -0.00108767 ...  0.00061626  0.00100642
#    0.00036059]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.176, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00020427  0.00060809  0.00073763 ... -0.00010388  0.00010863
#    0.00033809]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.24, shape=(), dtype=float32)
# tf.Tensor(
# [[ 6.2249354e-05 -5.7517056e-04 -3.6396281e-04 ...  1.7686197e-04
#    4.9027527e-04  7.7656424e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.304, shape=(), dtype=float32)
# tf.Tensor([[0.00098718 0.00093579 0.00132739 ... 0.00066168 0.00041829 0.0001624 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.368, shape=(), dtype=float32)
# tf.Tensor(
# [[ 1.4870655e-04  1.9446587e-05  1.9785984e-04 ... -3.7523566e-04
#   -4.9104181e-04 -6.6304157e-05]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.432, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00071384  0.00104345  0.00041727 ...  0.00046515 -0.00021149
#   -0.00061998]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.496, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00010394  0.0001476  -0.0007695  ... -0.00064545 -0.00078517
#   -0.00017103]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.56, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00106344  0.00155628  0.00088173 ... -0.00033294 -0.00058705
#   -0.00079188]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.624, shape=(), dtype=float32)
# tf.Tensor(
# [[ 3.3072629e-05  9.2470023e-04  1.4476570e-03 ... -6.0145720e-04
#   -1.5606753e-03 -1.1441591e-03]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.688, shape=(), dtype=float32)
# tf.Tensor(
# [[-5.9115130e-04 -8.1481942e-04 -1.3663964e-03 ...  6.0763030e-04
#   -8.8541392e-06 -2.3070052e-04]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.752, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00051127 -0.00083415  0.0001646  ... -0.00089375 -0.00183482
#   -0.0017146 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.816, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00056896  0.00075965  0.0010374  ...  0.00144778  0.00234253
#    0.00326961]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.88, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00270293  0.00106467 -0.00061119 ... -0.00064474 -0.0003834
#   -0.00017853]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_007.wav', shape=(), dtype=string) tf.Tensor(2.944, shape=(), dtype=float32)
# tf.Tensor(
# [[-7.2252972e-04 -1.4629998e-03 -1.3247849e-03 ...  9.5315574e-04
# ...
# tf.Tensor([[0.08711278 0.07467924 0.09641406 ... 0.08698438 0.11662634 0.11454415]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.632, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.11331397  0.1510177   0.14875305 ... -0.11862631 -0.13597402
#   -0.1523334 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.696, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.14272171 -0.14510565 -0.14345524 ...  0.03462477  0.04028913
#   -0.02027688]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.76, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01493916  0.03298137 -0.02421189 ...  0.08223779  0.06514594
#    0.01260322]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.824, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00473383 -0.00775103 -0.04853866 ... -0.01179728 -0.01263771
#    0.01808811]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.888, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02454617  0.0148185   0.02004749 ... -0.05260246 -0.00556492
#   -0.03900702]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(5.952, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05192354 -0.09217465 -0.05947243 ... -0.08881225 -0.08013605
#   -0.06622061]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.016, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05872829 -0.02875001 -0.0299164  ...  0.09293541  0.07470788
#    0.06071153]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.08, shape=(), dtype=float32)
# tf.Tensor([[0.01657511 0.05089191 0.05451935 ... 0.06086107 0.0509476  0.00163403]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.144, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00106904 -0.01716037 -0.02644489 ...  0.04887599  0.03729132
#    0.00868465]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.208, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00072352 -0.01264145 -0.00767636 ... -0.03202818 -0.04994132
#   -0.04360121]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.272, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04289329  0.02579685  0.03128137 ...  0.1644897   0.06994008
#    0.02718201]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.336, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03383093  0.03828368 -0.01838178 ... -0.02857882 -0.09740686
#   -0.14107414]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.4, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.10125338 -0.0500134  -0.04973356 ... -0.06221004 -0.05354275
#   -0.06006066]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.464, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.07398195 -0.05848208 -0.10236374 ...  0.03163422  0.06015404
#    0.07321562]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.528, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03068628  0.00404263  0.02815826 ... -0.06027811 -0.0855308
#   -0.12255491]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.592, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.11662807 -0.12310156 -0.08919513 ... -0.05698008 -0.06252028
#   -0.05635917]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.656, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.09116673 -0.11918828 -0.10838512 ... -0.11431883 -0.0944643
#   -0.09510897]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.72, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.12399921 -0.1303238  -0.12748    ...  0.01268262  0.02433264
#   -0.01812572]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.784, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02507983 -0.00236221  0.08488709 ... -0.07050075 -0.0812061
#   -0.06447387]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.848, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03596344 -0.04631432  0.02373014 ...  0.07050862  0.0711154
#   -0.0043872 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.912, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00645305 -0.01499558 -0.05544561 ...  0.00222292  0.07195804
#    0.03226174]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(6.976, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0164341  -0.02270115 -0.01727555 ...  0.11216695  0.10996882
#    0.08358066]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.04, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0790178   0.06451082  0.06301455 ... -0.01595204 -0.02049027
#    0.02353616]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.104, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.06075439  0.06536097  0.00154968 ... -0.103586   -0.02185765
#   -0.02527796]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.168, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0211971  -0.00131178 -0.00906163 ...  0.06773246  0.05099584
#    0.03059997]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.232, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00947358 -0.00278415 -0.01203443 ... -0.06306986 -0.04387894
#   -0.04070589]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.296, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02842685 -0.04718098 -0.04816718 ...  0.03736184  0.05258517
#    0.01397826]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.36, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02533246 -0.03808515 -0.08702055 ...  0.05144901  0.05522728
#    0.06974215]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.424, shape=(), dtype=float32)
# tf.Tensor([[0.09178557 0.05331159 0.0213232  ... 0.02403122 0.06759845 0.05005964]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.488, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.03803139  0.01683402  0.03409198 ... -0.0048693  -0.00841753
#   -0.0203837 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.552, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00753157 -0.01232157 -0.00995393 ...  0.03507371  0.01985049
#    0.01105004]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.616, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0095259  -0.0010815  -0.00651697 ... -0.04228503 -0.04020514
#   -0.04367915]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.68, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0510122  -0.06593101 -0.08594091 ...  0.03050566  0.01925674
#    0.00649984]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.744, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00888665 -0.0157342  -0.00851827 ...  0.01492164  0.0159588
#    0.01528103]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.808, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.01495281  0.01229498  0.01015852 ...  0.00043418  0.00157774
#   -0.0033839 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.872, shape=(), dtype=float32)
# tf.Tensor([[0.01324351 0.01825207 0.00288817 ... 0.04975609 0.04610872 0.05007932]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(7.936, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05407363  0.04899692  0.04496911 ... -0.02970025 -0.02839194
#   -0.02907558]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.0, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02830249 -0.02397087 -0.02059586 ... -0.01299311 -0.02109201
#   -0.01800098]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.064, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00467627 -0.00680697 -0.01200823 ...  0.01870628  0.01596149
#    0.0052078 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.128, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01375964 -0.02564771 -0.02635411 ...  0.08684918  0.09453402
#    0.10040306]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.192, shape=(), dtype=float32)
# tf.Tensor([[0.07897978 0.05304905 0.03295523 ... 0.03460511 0.04124347 0.04734996]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.256, shape=(), dtype=float32)
# tf.Tensor([[0.06017576 0.05426955 0.04361796 ... 0.03309142 0.04302317 0.05268005]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.32, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.05700127  0.0613451   0.06118121 ... -0.01314454 -0.01495361
#   -0.01278387]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.384, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01572978 -0.01350191 -0.01941849 ...  0.00283687  0.00789044
#    0.01353848]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.448, shape=(), dtype=float32)
# tf.Tensor([[0.01865115 0.02902894 0.02881768 ... 0.01955965 0.02699698 0.03184038]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.512, shape=(), dtype=float32)
# tf.Tensor([[0.02589969 0.00988458 0.00033702 ... 0.00891453 0.00534743 0.01040929]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.576, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00528471 -0.0002351  -0.00343826 ... -0.03674319 -0.03852505
#   -0.02829999]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.64, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02434372 -0.02248098 -0.02139794 ...  0.0098204  -0.00205354
#   -0.01049568]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.704, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01290999 -0.02005435 -0.02566916 ... -0.01257833 -0.00449222
#    0.00380085]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.768, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00493896  0.0167303   0.01276487 ... -0.00598727 -0.00034789
#   -0.0071794 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.832, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01298184 -0.01683013 -0.01524189 ...  0.00666299  0.00597413
#    0.00795448]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.896, shape=(), dtype=float32)
# tf.Tensor([[0.0181874  0.01967229 0.02637126 ... 0.02662926 0.02959646 0.02961078]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(8.96, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.02874999  0.0267708   0.02635065 ... -0.01491079 -0.02160954
#   -0.023555  ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.024, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03198367 -0.02759651 -0.01876784 ... -0.00841853 -0.01309546
#   -0.00863695]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.088, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00379984 -0.00087338 -0.00576076 ...  0.03352652  0.02232303
#    0.01116032]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.152, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.00379602  0.00993068  0.01230766 ...  0.02188811  0.00126101
#   -0.00469774]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.216, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.0010288   0.0108811   0.00404404 ...  0.00023216 -0.01235749
#   -0.0254667 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.28, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02323036 -0.01630403 -0.01170498 ... -0.02180168 -0.02709866
#   -0.04274084]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.344, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.04347578 -0.02671895 -0.02457044 ... -0.03727229 -0.04330532
#   -0.05837788]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.408, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.05283015 -0.04888634 -0.04968477 ... -0.03000796 -0.03520559
#   -0.03470027]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.472, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02632757 -0.01880952 -0.01413576 ...  0.01140081  0.01118992
#    0.00718776]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.536, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.00014085 -0.00120279 -0.00549118 ...  0.02363413  0.0301076
#    0.02346862]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.6, shape=(), dtype=float32)
# tf.Tensor([[0.01304412 0.01892575 0.01760167 ... 0.04123082 0.04357724 0.04899686]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.664, shape=(), dtype=float32)
# tf.Tensor(
# [[ 0.0536246   0.05521827  0.04801179 ... -0.02445913 -0.02060817
#   -0.02658857]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.728, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.03484216 -0.04002912 -0.02715168 ...  0.00121286 -0.00583982
#   -0.01122194]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.792, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.01437529 -0.01063475 -0.00931296 ... -0.0120769  -0.01706786
#   -0.0221983 ]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.856, shape=(), dtype=float32)
# tf.Tensor(
# [[-0.02145907 -0.02299646 -0.02495861 ...  0.031418    0.03245335
#    0.03018465]], shape=(1, 1024), dtype=float32) tf.Tensor(b'data/test_data/DRONE_001.wav', shape=(), dtype=string) tf.Tensor(9.92, shape=(), dtype=float32)

# %%
predictions_with_metadata
# Out:
# [('data/test_data/DRONE_018.wav',
#   0.0,
#   array([[0.04933938, 0.9506606 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.064,
#   array([[0.9961493 , 0.00385076]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.128,
#   array([[0.97818655, 0.02181345]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.192,
#   array([[1.0000000e+00, 2.6974884e-11]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.256,
#   array([[9.9993694e-01, 6.3089828e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.32,
#   array([[0.14938587, 0.8506141 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.384,
#   array([[9.9999905e-01, 8.9700461e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.448,
#   array([[0.6690464 , 0.33095357]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.512,
#   array([[9.9967492e-01, 3.2513813e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.576,
#   array([[2.721835e-08, 1.000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.64,
#   array([[2.8870115e-09, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.704,
#   array([[0.53571117, 0.46428886]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.768,
#   array([[4.8056099e-06, 9.9999523e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.832,
#   array([[1.000000e+00, 8.370136e-11]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   0.896,
#   array([[0.03267369, 0.9673263 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   0.96,
#   array([[0.00123653, 0.99876344]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.024,
#   array([[9.999999e-01, 7.967011e-08]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.088,
#   array([[1.000000e+00, 7.869508e-12]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.152,
#   array([[1.1568421e-09, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.216,
#   array([[1.000000e+00, 4.692054e-10]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.28,
#   array([[7.107378e-04, 9.992893e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.344,
#   array([[0.15818813, 0.84181184]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.408,
#   array([[0.03354235, 0.96645766]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.472,
#   array([[9.9999988e-01, 1.0468823e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.536,
#   array([[2.7891314e-05, 9.9997211e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.6,
#   array([[0.06829637, 0.9317037 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.664,
#   array([[0.09542237, 0.9045776 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.728,
#   array([[0.99598265, 0.00401738]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.792,
#   array([[1.0000000e+00, 2.1380434e-12]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.856,
#   array([[3.8970395e-13, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   1.92,
#   array([[9.9999630e-01, 3.6882561e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   1.984,
#   array([[0.9904483 , 0.00955165]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.048,
#   array([[1.0000000e+00, 1.4667831e-08]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.112,
#   array([[1.000000e+00, 7.834743e-13]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.176,
#   array([[0.4883436 , 0.51165634]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.24,
#   array([[4.6194171e-05, 9.9995375e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.304,
#   array([[2.8482889e-06, 9.9999714e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.368,
#   array([[9.9997485e-01, 2.5102168e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.432,
#   array([[2.734478e-13, 1.000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.496,
#   array([[0.00107649, 0.9989235 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.56,
#   array([[0.08146743, 0.91853255]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.624,
#   array([[1.0015928e-05, 9.9998999e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.688,
#   array([[2.3984845e-09, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.752,
#   array([[0.9523457 , 0.04765419]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.816,
#   array([[0.01097822, 0.9890218 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   2.88,
#   array([[0.99693346, 0.00306653]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   2.944,
#   array([[0.00547839, 0.9945216 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.008,
#   array([[0.26975328, 0.73024666]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.072,
#   array([[9.9999964e-01, 3.4056674e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.136,
#   array([[1.00000e+00, 2.67685e-10]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.2,
#   array([[8.088785e-08, 9.999999e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.264,
#   array([[0.46340674, 0.53659326]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.328,
#   array([[0.00414961, 0.99585044]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.392,
#   array([[9.9964774e-01, 3.5221741e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.456,
#   array([[9.9994051e-01, 5.9490907e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.52,
#   array([[1.0000000e+00, 9.8383815e-11]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.584,
#   array([[0.00173766, 0.99826235]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.648,
#   array([[0.20249544, 0.7975046 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.712,
#   array([[0.01376003, 0.98623997]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   3.776,
#   array([[0.805001  , 0.19499902]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.84,
#   array([[9.999372e-01, 6.279373e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.904,
#   array([[9.9987161e-01, 1.2835812e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   3.968,
#   array([[0.93398577, 0.06601422]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.032,
#   array([[4.573911e-04, 9.995426e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.096,
#   array([[0.4220953, 0.5779047]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.16,
#   array([[0.89641774, 0.10358226]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.224,
#   array([[0.996222  , 0.00377797]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.288,
#   array([[9.9999321e-01, 6.7637916e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.352,
#   array([[0.00563215, 0.9943679 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.416,
#   array([[0.00716241, 0.9928376 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.48,
#   array([[0.9967097 , 0.00329026]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.544,
#   array([[0.02838026, 0.9716197 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.608,
#   array([[0.7550767 , 0.24492323]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.672,
#   array([[0.984452  , 0.01554806]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   4.736,
#   array([[0.02472465, 0.9752754 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.8,
#   array([[0.23959696, 0.76040304]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.864,
#   array([[0.07859758, 0.92140245]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.928,
#   array([[0.16797024, 0.83202976]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   4.992,
#   array([[0.99828327, 0.00171676]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.056,
#   array([[0.80205   , 0.19795004]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.12,
#   array([[0.96136767, 0.03863232]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.184,
#   array([[0.37712207, 0.6228779 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.248,
#   array([[9.9999475e-01, 5.1865950e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.312,
#   array([[0.00272457, 0.9972754 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.376,
#   array([[0.29525515, 0.7047448 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.44,
#   array([[0.916966, 0.083034]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.504,
#   array([[9.991055e-01, 8.945053e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.568,
#   array([[1.0000000e+00, 1.4807879e-15]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.632,
#   array([[0.8394524 , 0.16054761]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.696,
#   array([[0.11590067, 0.8840993 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.76,
#   array([[0.02199595, 0.9780041 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.824,
#   array([[2.6992253e-05, 9.9997306e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   5.888,
#   array([[9.9959403e-01, 4.0601558e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   5.952,
#   array([[0.6538319, 0.3461681]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.016,
#   array([[0.9841541 , 0.01584582]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.08,
#   array([[0.95526904, 0.04473098]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.144,
#   array([[1.0000000e+00, 2.9751784e-10]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.208,
#   array([[0.99840814, 0.00159191]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.272,
#   array([[1.000000e+00, 5.419593e-09]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.336,
#   array([[0.9983918 , 0.00160818]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.4,
#   array([[9.691738e-09, 1.000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.464,
#   array([[1.0000000e+00, 1.5962769e-08]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.528,
#   array([[0.99833304, 0.00166699]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.592,
#   array([[0.80423665, 0.19576341]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   6.656,
#   array([[2.3526051e-04, 9.9976474e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.72,
#   array([[0.23748901, 0.762511  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.784,
#   array([[0.02594719, 0.9740528 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.848,
#   array([[1.8791833e-04, 9.9981207e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.912,
#   array([[0.05620085, 0.9437992 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   6.976,
#   array([[0.9100738 , 0.08992618]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.04,
#   array([[0.8491491 , 0.15085092]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.104,
#   array([[0.8511533 , 0.14884664]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.168,
#   array([[9.9999988e-01, 1.0238296e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.232,
#   array([[0.02916398, 0.97083604]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   7.296,
#   array([[1.0000000e+00, 1.1238791e-09]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.36,
#   array([[2.0738673e-09, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   7.424,
#   array([[0.0136142, 0.9863858]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   7.488,
#   array([[0.9855745 , 0.01442554]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.552,
#   array([[0.9257679 , 0.07423207]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.616,
#   array([[8.6331525e-10, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   7.68,
#   array([[0.0752358 , 0.92476416]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   7.744,
#   array([[9.999994e-01, 5.612564e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.808,
#   array([[1.000000e+00, 1.563042e-12]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.872,
#   array([[0.8705819 , 0.12941806]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   7.936,
#   array([[0.9982261 , 0.00177387]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.0,
#   array([[0.69938755, 0.30061248]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.064,
#   array([[0.7065143 , 0.29348567]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.128,
#   array([[5.9193935e-06, 9.9999404e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.192,
#   array([[0.845135  , 0.15486504]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.256,
#   array([[0.04538767, 0.9546123 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.32,
#   array([[9.9999833e-01, 1.7113786e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.384,
#   array([[0.9595752 , 0.04042488]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.448,
#   array([[0.02845168, 0.9715484 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.512,
#   array([[1.3247967e-05, 9.9998677e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.576,
#   array([[4.5536796e-04, 9.9954456e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.64,
#   array([[9.9999893e-01, 1.0658716e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.704,
#   array([[9.9986911e-01, 1.3084775e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.768,
#   array([[0.99626416, 0.00373587]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   8.832,
#   array([[3.0579642e-05, 9.9996936e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.896,
#   array([[5.629283e-14, 1.000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   8.96,
#   array([[0.04369102, 0.9563089 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.024,
#   array([[1.0000000e+00, 2.8272484e-09]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.088,
#   array([[0.9975528 , 0.00244716]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.152,
#   array([[0.3781597, 0.6218403]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.216,
#   array([[0.91729885, 0.08270118]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.28,
#   array([[0.68572557, 0.31427437]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.344,
#   array([[0.48676845, 0.5132316 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.408,
#   array([[0.03845062, 0.9615494 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.472,
#   array([[9.9975282e-01, 2.4715296e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.536,
#   array([[0.25805604, 0.741944  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.6,
#   array([[1.0000000e+00, 2.0810006e-08]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.664,
#   array([[0.14216605, 0.8578339 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.728,
#   array([[0.89209497, 0.107905  ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.792,
#   array([[0.9634199 , 0.03658009]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_018.wav',
#   9.856,
#   array([[9.0151174e-05, 9.9990988e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_018.wav',
#   9.92,
#   array([[9.999994e-01, 5.440983e-07]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_007.wav',
#   0.0,
#   array([[0.35149455, 0.6485055 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.064,
#   array([[0.34788918, 0.6521109 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.128,
#   array([[0.32916924, 0.6708308 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.192,
#   array([[0.3440292 , 0.65597075]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.256,
#   array([[0.34170893, 0.65829104]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.32,
#   array([[0.35100657, 0.6489935 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.384,
#   array([[0.33979988, 0.6602001 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.448,
#   array([[0.35091946, 0.6490806 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.512,
#   array([[0.3513698, 0.6486302]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.576,
#   array([[0.31516418, 0.68483573]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.64,
#   array([[0.3482244, 0.6517756]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.704,
#   array([[0.37623858, 0.6237614 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.768,
#   array([[0.33575615, 0.6642438 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.832,
#   array([[0.35425818, 0.64574176]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.896,
#   array([[0.33566895, 0.6643311 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   0.96,
#   array([[0.28393286, 0.7160672 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.024,
#   array([[0.3368096, 0.6631904]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.088,
#   array([[0.36650768, 0.63349235]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.152,
#   array([[0.34447694, 0.65552306]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.216,
#   array([[0.34735537, 0.6526446 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.28,
#   array([[0.35065344, 0.64934653]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.344,
#   array([[0.346172, 0.653828]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.408,
#   array([[0.35135052, 0.64864945]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.472,
#   array([[0.33758342, 0.6624166 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.536,
#   array([[0.35633254, 0.6436674 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.6,
#   array([[0.35859993, 0.64140004]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.664,
#   array([[0.35026643, 0.6497335 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.728,
#   array([[0.35080191, 0.6491981 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.792,
#   array([[0.33287996, 0.66712004]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.856,
#   array([[0.34091917, 0.6590808 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.92,
#   array([[0.34428474, 0.6557152 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   1.984,
#   array([[0.34896475, 0.6510353 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.048,
#   array([[0.34540385, 0.65459615]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.112,
#   array([[0.34974134, 0.6502586 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.176,
#   array([[0.3561735 , 0.64382654]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.24,
#   array([[0.34590697, 0.654093  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.304,
#   array([[0.35477695, 0.645223  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.368,
#   array([[0.3033058, 0.6966942]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.432,
#   array([[0.3575156, 0.6424844]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.496,
#   array([[0.3135682, 0.6864318]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.56,
#   array([[0.33790457, 0.6620954 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.624,
#   array([[0.33875674, 0.6612433 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.688,
#   array([[0.3337783, 0.6662217]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.752,
#   array([[0.3475471, 0.6524529]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.816,
#   array([[0.34383956, 0.6561604 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.88,
#   array([[0.30893692, 0.69106305]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   2.944,
#   array([[0.34732825, 0.6526718 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.008,
#   array([[0.33047122, 0.6695287 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.072,
#   array([[0.3481671 , 0.65183294]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.136,
#   array([[0.3176556 , 0.68234444]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.2,
#   array([[0.3239822, 0.6760178]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.264,
#   array([[0.33876607, 0.6612339 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.328,
#   array([[0.33146, 0.66854]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.392,
#   array([[0.35408476, 0.6459153 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.456,
#   array([[0.3445785, 0.6554215]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.52,
#   array([[0.3344261 , 0.66557384]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.584,
#   array([[0.32492968, 0.6750703 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.648,
#   array([[0.3466482, 0.6533518]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.712,
#   array([[0.34851912, 0.65148085]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.776,
#   array([[0.32856363, 0.6714363 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.84,
#   array([[0.35893488, 0.6410651 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.904,
#   array([[0.34413454, 0.6558655 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   3.968,
#   array([[0.33772117, 0.66227883]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.032,
#   array([[0.34838995, 0.65161   ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.096,
#   array([[0.34179464, 0.65820533]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.16,
#   array([[0.3366795, 0.6633205]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.224,
#   array([[0.33316302, 0.666837  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.288,
#   array([[0.3333495 , 0.66665053]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.352,
#   array([[0.33592847, 0.6640715 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.416,
#   array([[0.3277631 , 0.67223686]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.48,
#   array([[0.3630878 , 0.63691217]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.544,
#   array([[0.35699448, 0.64300555]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.608,
#   array([[0.34218764, 0.6578123 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.672,
#   array([[0.34696394, 0.653036  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.736,
#   array([[0.34712294, 0.65287703]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.8,
#   array([[0.34791857, 0.65208143]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.864,
#   array([[0.34119377, 0.6588062 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.928,
#   array([[0.34300715, 0.65699285]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   4.992,
#   array([[0.34277675, 0.6572232 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.056,
#   array([[0.33448577, 0.66551423]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.12,
#   array([[0.34571522, 0.65428483]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.184,
#   array([[0.33312625, 0.66687375]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.248,
#   array([[0.3081338 , 0.69186616]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.312,
#   array([[0.34460908, 0.6553909 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.376,
#   array([[0.3518351, 0.6481649]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.44,
#   array([[0.3312769 , 0.66872305]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.504,
#   array([[0.32918534, 0.6708147 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.568,
#   array([[0.35064295, 0.649357  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.632,
#   array([[0.35256177, 0.64743817]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.696,
#   array([[0.3556084 , 0.64439166]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.76,
#   array([[0.33912995, 0.6608701 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.824,
#   array([[0.3301047, 0.6698953]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.888,
#   array([[0.3526245 , 0.64737546]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   5.952,
#   array([[0.33520895, 0.664791  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.016,
#   array([[0.34732023, 0.65267974]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.08,
#   array([[0.33477622, 0.66522384]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.144,
#   array([[0.33400303, 0.66599697]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.208,
#   array([[0.34628955, 0.6537104 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.272,
#   array([[0.33734074, 0.6626593 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.336,
#   array([[0.34287944, 0.6571206 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.4,
#   array([[0.32248062, 0.67751944]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.464,
#   array([[0.3470017 , 0.65299827]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.528,
#   array([[0.35624835, 0.6437516 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.592,
#   array([[0.35319895, 0.6468011 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.656,
#   array([[0.34112176, 0.65887827]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.72,
#   array([[0.35557854, 0.64442146]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.784,
#   array([[0.3456612 , 0.65433884]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.848,
#   array([[0.34392625, 0.6560738 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.912,
#   array([[0.3471551, 0.6528449]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   6.976,
#   array([[0.34577397, 0.65422606]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.04,
#   array([[0.3425509 , 0.65744907]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.104,
#   array([[0.34370077, 0.65629923]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.168,
#   array([[0.3334181, 0.6665819]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.232,
#   array([[0.35281822, 0.6471818 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.296,
#   array([[0.34072906, 0.65927094]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.36,
#   array([[0.3384884 , 0.66151166]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.424,
#   array([[0.35180914, 0.6481909 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.488,
#   array([[0.34644744, 0.6535526 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.552,
#   array([[0.34215578, 0.6578442 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.616,
#   array([[0.3529951 , 0.64700496]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.68,
#   array([[0.3433208, 0.6566792]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.744,
#   array([[0.32703087, 0.6729691 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.808,
#   array([[0.34461462, 0.6553853 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.872,
#   array([[0.35144752, 0.6485524 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   7.936,
#   array([[0.35176608, 0.6482339 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.0,
#   array([[0.3444061, 0.6555939]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.064,
#   array([[0.34683457, 0.6531654 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.128,
#   array([[0.3465499, 0.6534501]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.192,
#   array([[0.34243995, 0.65756005]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.256,
#   array([[0.3449809, 0.6550191]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.32,
#   array([[0.3463417 , 0.65365833]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.384,
#   array([[0.34680578, 0.6531942 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.448,
#   array([[0.3457705, 0.6542295]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.512,
#   array([[0.34903175, 0.6509683 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.576,
#   array([[0.34495622, 0.6550438 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.64,
#   array([[0.34095117, 0.6590488 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.704,
#   array([[0.3475379, 0.6524621]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.768,
#   array([[0.3341764 , 0.66582364]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.832,
#   array([[0.3417081, 0.6582919]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.896,
#   array([[0.3481632, 0.6518368]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   8.96,
#   array([[0.34565982, 0.65434015]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.024,
#   array([[0.33883694, 0.66116303]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.088,
#   array([[0.34569225, 0.6543078 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.152,
#   array([[0.34490967, 0.6550903 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.216,
#   array([[0.34682363, 0.65317637]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.28,
#   array([[0.34634867, 0.6536513 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.344,
#   array([[0.34682575, 0.65317434]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.408,
#   array([[0.3430004 , 0.65699965]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.472,
#   array([[0.3396375, 0.6603625]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.536,
#   array([[0.3495234, 0.6504766]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.6,
#   array([[0.35197568, 0.6480243 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.664,
#   array([[0.33513087, 0.6648691 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.728,
#   array([[0.34741655, 0.6525835 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.792,
#   array([[0.34275684, 0.65724313]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.856,
#   array([[0.35138333, 0.6486166 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_007.wav',
#   9.92,
#   array([[0.34370145, 0.6562985 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.0,
#   array([[0.00437253, 0.9956274 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.064,
#   array([[0.06559985, 0.93440014]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.128,
#   array([[0.7576812 , 0.24231881]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.192,
#   array([[2.8728286e-05, 9.9997127e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.256,
#   array([[9.9999166e-01, 8.3972554e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.32,
#   array([[9.9988425e-01, 1.1579584e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.384,
#   array([[0.9914698 , 0.00853017]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.448,
#   array([[9.9959463e-01, 4.0538053e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.512,
#   array([[0.96543926, 0.03456074]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.576,
#   array([[0.03499699, 0.965003  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.64,
#   array([[9.991891e-01, 8.108925e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   0.704,
#   array([[0.14459968, 0.8554003 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.768,
#   array([[3.7441670e-04, 9.9962556e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.832,
#   array([[0.49816203, 0.50183797]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.896,
#   array([[0.37818635, 0.62181365]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   0.96,
#   array([[4.7154014e-04, 9.9952853e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.024,
#   array([[0.99895716, 0.00104277]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.088,
#   array([[6.5328705e-04, 9.9934667e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.152,
#   array([[0.92646974, 0.07353023]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.216,
#   array([[0.98464936, 0.0153506 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.28,
#   array([[0.15278068, 0.8472193 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.344,
#   array([[0.8073443 , 0.19265565]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.408,
#   array([[9.505974e-05, 9.999050e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.472,
#   array([[0.43050963, 0.5694904 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.536,
#   array([[0.00499241, 0.9950075 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.6,
#   array([[0.88836765, 0.11163233]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.664,
#   array([[0.00217485, 0.99782515]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.728,
#   array([[0.00997337, 0.9900267 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.792,
#   array([[0.22737977, 0.7726202 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.856,
#   array([[4.2206910e-04, 9.9957794e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   1.92,
#   array([[0.6333891 , 0.36661085]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   1.984,
#   array([[0.00983145, 0.9901686 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   2.048,
#   array([[9.995407e-01, 4.593298e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.112,
#   array([[0.9953205 , 0.00467947]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.176,
#   array([[0.5629788, 0.4370212]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.24,
#   array([[0.988257  , 0.01174305]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.304,
#   array([[9.9966335e-01, 3.3669721e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.368,
#   array([[0.04569098, 0.954309  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   2.432,
#   array([[0.05429436, 0.9457057 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   2.496,
#   array([[9.999932e-01, 6.785228e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.56,
#   array([[0.79008394, 0.20991606]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.624,
#   array([[9.9987864e-01, 1.2137326e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.688,
#   array([[0.66626596, 0.33373412]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.752,
#   array([[9.9993908e-01, 6.0911363e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   2.816,
#   array([[0.2744028, 0.7255972]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   2.88,
#   array([[1.6591015e-06, 9.9999833e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   2.944,
#   array([[0.06088158, 0.93911844]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.008,
#   array([[0.9834152 , 0.01658486]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.072,
#   array([[0.9558752 , 0.04412477]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.136,
#   array([[0.14460628, 0.85539377]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.2,
#   array([[1.2935603e-05, 9.9998701e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.264,
#   array([[0.7125295, 0.2874705]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.328,
#   array([[6.1891224e-06, 9.9999380e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.392,
#   array([[0.99606055, 0.00393937]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.456,
#   array([[0.7599843 , 0.24001572]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.52,
#   array([[9.9943668e-01, 5.6331843e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.584,
#   array([[0.9435045 , 0.05649551]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.648,
#   array([[0.98301446, 0.0169855 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.712,
#   array([[2.6292317e-05, 9.9997365e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.776,
#   array([[0.8552572 , 0.14474279]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   3.84,
#   array([[0.43750137, 0.5624987 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.904,
#   array([[0.00391422, 0.99608576]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   3.968,
#   array([[0.07028174, 0.92971826]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.032,
#   array([[9.9955291e-01, 4.4703152e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.096,
#   array([[9.9958807e-01, 4.1189854e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.16,
#   array([[0.00246319, 0.9975368 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.224,
#   array([[0.00419487, 0.99580514]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.288,
#   array([[0.09685718, 0.9031428 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.352,
#   array([[0.95993304, 0.04006694]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.416,
#   array([[0.95801735, 0.04198265]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.48,
#   array([[0.3037725 , 0.69622755]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.544,
#   array([[0.04177346, 0.9582265 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.608,
#   array([[0.97371984, 0.02628016]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.672,
#   array([[0.9634821, 0.0365179]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.736,
#   array([[0.9424429 , 0.05755712]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   4.8,
#   array([[0.00226064, 0.9977393 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.864,
#   array([[0.00669431, 0.99330574]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.928,
#   array([[1.0098204e-09, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   4.992,
#   array([[9.9960285e-01, 3.9717698e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.056,
#   array([[0.16064268, 0.83935726]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.12,
#   array([[9.999999e-01, 8.538426e-08]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.184,
#   array([[0.18311213, 0.8168878 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.248,
#   array([[0.01314676, 0.98685324]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.312,
#   array([[0.3297316, 0.6702684]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.376,
#   array([[0.3102343 , 0.68976575]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.44,
#   array([[0.8123026 , 0.18769749]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.504,
#   array([[0.70445013, 0.29554987]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.568,
#   array([[9.9982470e-01, 1.7536242e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.632,
#   array([[0.8710811 , 0.12891887]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.696,
#   array([[0.00303587, 0.99696416]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.76,
#   array([[0.86408556, 0.13591452]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   5.824,
#   array([[0.31075892, 0.6892411 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.888,
#   array([[0.48062217, 0.5193778 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   5.952,
#   array([[0.05460622, 0.9453938 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.016,
#   array([[0.9436993 , 0.05630068]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   6.08,
#   array([[0.00211249, 0.99788755]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.144,
#   array([[0.9841045 , 0.01589546]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   6.208,
#   array([[0.31211752, 0.6878825 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.272,
#   array([[0.89575225, 0.10424769]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   6.336,
#   array([[0.33102286, 0.66897714]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.4,
#   array([[0.09045952, 0.9095405 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.464,
#   array([[0.2055196, 0.7944804]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.528,
#   array([[8.5363114e-05, 9.9991465e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.592,
#   array([[9.9951017e-01, 4.8986042e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   6.656,
#   array([[0.00716807, 0.99283195]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.72,
#   array([[0.00434313, 0.99565685]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.784,
#   array([[0.16093957, 0.8390604 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.848,
#   array([[0.99867237, 0.00132767]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   6.912,
#   array([[9.3643268e-04, 9.9906355e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   6.976,
#   array([[0.05110547, 0.9488945 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.04,
#   array([[0.29860997, 0.70139   ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.104,
#   array([[5.9653516e-04, 9.9940348e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.168,
#   array([[9.9975282e-01, 2.4721498e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   7.232,
#   array([[0.09182054, 0.9081794 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.296,
#   array([[7.7409044e-05, 9.9992263e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.36,
#   array([[0.00532139, 0.9946786 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.424,
#   array([[0.02291388, 0.9770861 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.488,
#   array([[0.02721243, 0.97278756]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.552,
#   array([[0.43546405, 0.56453586]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_016.wav',
#   7.616,
#   array([[0.61759293, 0.382407  ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_016.wav',
#   7.68,
#   array([[0.9989792 , 0.00102086]], dtype=float32),
#   array([0])),
# ...
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   4.864,
#   array([[0.65391403, 0.34608594]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   4.928,
#   array([[0.0280758 , 0.97192425]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   4.992,
#   array([[0.4370601, 0.5629399]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.056,
#   array([[0.38139144, 0.61860853]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.12,
#   array([[0.22009736, 0.77990264]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.184,
#   array([[0.1496821, 0.8503179]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.248,
#   array([[0.6509846 , 0.34901547]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.312,
#   array([[2.9365154e-04, 9.9970633e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.376,
#   array([[0.59403336, 0.4059666 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.44,
#   array([[0.443023  , 0.55697703]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   5.504,
#   array([[0.92919904, 0.07080095]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.568,
#   array([[0.9850376 , 0.01496237]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.632,
#   array([[0.54184806, 0.45815188]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.696,
#   array([[0.58907056, 0.41092944]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.76,
#   array([[0.8217297 , 0.17827033]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.824,
#   array([[0.78382766, 0.21617243]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.888,
#   array([[9.991736e-01, 8.263749e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   5.952,
#   array([[0.02824827, 0.97175175]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.016,
#   array([[0.03372296, 0.9662771 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.08,
#   array([[0.0030066, 0.9969934]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.144,
#   array([[7.3988274e-05, 9.9992597e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.208,
#   array([[0.996709  , 0.00329096]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.272,
#   array([[0.02721959, 0.97278035]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.336,
#   array([[9.9990869e-01, 9.1302165e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.4,
#   array([[1.0000000e+00, 2.1991098e-13]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.464,
#   array([[0.16616474, 0.8338353 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.528,
#   array([[0.36609477, 0.6339053 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.592,
#   array([[1.5434118e-06, 9.9999845e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.656,
#   array([[0.65649796, 0.34350204]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.72,
#   array([[0.9973877 , 0.00261231]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.784,
#   array([[0.12695235, 0.8730477 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.848,
#   array([[0.04226753, 0.95773244]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   6.912,
#   array([[0.64092094, 0.35907903]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   6.976,
#   array([[0.40702575, 0.5929742 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.04,
#   array([[0.17427617, 0.8257239 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.104,
#   array([[0.4239758, 0.5760242]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.168,
#   array([[0.02739883, 0.9726011 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.232,
#   array([[0.6293018 , 0.37069824]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   7.296,
#   array([[0.8589771, 0.1410229]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   7.36,
#   array([[1.0000000e+00, 2.0732715e-19]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   7.424,
#   array([[9.996778e-01, 3.221876e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   7.488,
#   array([[0.4015221, 0.5984779]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.552,
#   array([[0.1633575, 0.8366425]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.616,
#   array([[0.3606595 , 0.63934046]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.68,
#   array([[0.23318242, 0.76681757]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.744,
#   array([[0.21462168, 0.78537834]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.808,
#   array([[3.0778797e-04, 9.9969220e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.872,
#   array([[0.01509309, 0.9849069 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   7.936,
#   array([[0.95756483, 0.04243511]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.0,
#   array([[0.31979626, 0.6802037 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.064,
#   array([[0.38490257, 0.61509746]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.128,
#   array([[0.22626613, 0.7737339 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.192,
#   array([[0.4776623, 0.5223377]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.256,
#   array([[0.96232677, 0.0376732 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.32,
#   array([[0.01876719, 0.98123276]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.384,
#   array([[0.01721428, 0.98278576]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.448,
#   array([[0.700574  , 0.29942596]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.512,
#   array([[0.9011149 , 0.09888516]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.576,
#   array([[0.8066947, 0.1933054]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.64,
#   array([[0.01227137, 0.9877286 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.704,
#   array([[0.00776771, 0.9922323 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.768,
#   array([[0.02716241, 0.97283757]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.832,
#   array([[0.00897451, 0.9910255 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   8.896,
#   array([[0.8340163 , 0.16598362]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   8.96,
#   array([[1.674666e-04, 9.998325e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.024,
#   array([[0.9878399 , 0.01216014]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.088,
#   array([[0.135128, 0.864872]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.152,
#   array([[9.9956638e-01, 4.3359716e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.216,
#   array([[0.86931103, 0.13068894]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.28,
#   array([[0.21420299, 0.785797  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.344,
#   array([[1.0000000e+00, 2.4229619e-15]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.408,
#   array([[1.8429373e-11, 1.0000000e+00]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.472,
#   array([[9.999504e-01, 4.964319e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.536,
#   array([[9.9991333e-01, 8.6648579e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.6,
#   array([[0.97563815, 0.0243618 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.664,
#   array([[1.361137e-06, 9.999987e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.728,
#   array([[2.2367398e-07, 9.9999976e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.792,
#   array([[0.44211903, 0.557881  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_013.wav',
#   9.856,
#   array([[1.00000e+00, 3.82304e-14]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_013.wav',
#   9.92,
#   array([[5.9140377e-05, 9.9994087e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.0,
#   array([[0.40881878, 0.5911813 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.064,
#   array([[0.91434383, 0.08565618]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.128,
#   array([[0.89599824, 0.10400174]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.192,
#   array([[3.694200e-04, 9.996306e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.256,
#   array([[0.95554084, 0.04445916]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.32,
#   array([[0.9965779 , 0.00342202]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.384,
#   array([[5.489212e-04, 9.994511e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.448,
#   array([[0.84622633, 0.1537737 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.512,
#   array([[9.9974018e-01, 2.5977075e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.576,
#   array([[9.9999785e-01, 2.1317094e-06]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.64,
#   array([[0.9951167 , 0.00488328]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.704,
#   array([[0.00119478, 0.99880517]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.768,
#   array([[0.89234483, 0.1076552 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   0.832,
#   array([[0.08785803, 0.9121419 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.896,
#   array([[0.21069777, 0.78930223]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   0.96,
#   array([[0.99361926, 0.00638065]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   1.024,
#   array([[7.5889856e-04, 9.9924111e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.088,
#   array([[0.9922174 , 0.00778257]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   1.152,
#   array([[1.5019505e-05, 9.9998498e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.216,
#   array([[9.994242e-01, 5.757599e-04]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   1.28,
#   array([[0.34108105, 0.658919  ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.344,
#   array([[0.8383511 , 0.16164891]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   1.408,
#   array([[0.02523994, 0.9747601 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.472,
#   array([[1.6963375e-05, 9.9998307e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.536,
#   array([[0.25255403, 0.74744594]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.6,
#   array([[0.02330259, 0.97669744]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.664,
#   array([[0.02373289, 0.9762671 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.728,
#   array([[8.640501e-05, 9.999136e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.792,
#   array([[0.6228741 , 0.37712592]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   1.856,
#   array([[0.3101969, 0.6898031]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.92,
#   array([[1.1082718e-04, 9.9988914e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   1.984,
#   array([[0.92046875, 0.07953122]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.048,
#   array([[0.00313109, 0.9968689 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.112,
#   array([[0.7836859 , 0.21631406]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.176,
#   array([[0.9533391, 0.0466609]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.24,
#   array([[9.9994838e-01, 5.1667386e-05]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.304,
#   array([[0.5278981 , 0.47210193]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.368,
#   array([[0.6561765, 0.3438235]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.432,
#   array([[0.4055345, 0.5944655]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.496,
#   array([[0.5418223, 0.4581777]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.56,
#   array([[0.36786255, 0.6321374 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.624,
#   array([[0.03004047, 0.96995956]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.688,
#   array([[1.0110892e-04, 9.9989891e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.752,
#   array([[0.9824922 , 0.01750776]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.816,
#   array([[0.97242457, 0.02757546]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   2.88,
#   array([[0.27563584, 0.72436416]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   2.944,
#   array([[0.00274478, 0.99725527]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   3.008,
#   array([[0.80554724, 0.1944528 ]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.072,
#   array([[0.8272993 , 0.17270066]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.136,
#   array([[0.9929872 , 0.00701284]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.2,
#   array([[0.98285645, 0.01714353]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.264,
#   array([[0.00418213, 0.99581784]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   3.328,
#   array([[0.8416184 , 0.15838154]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.392,
#   array([[0.00674683, 0.9932532 ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   3.456,
#   array([[0.7376772 , 0.26232275]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.52,
#   array([[0.9548281 , 0.04517191]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.584,
#   array([[0.8573732 , 0.14262675]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.648,
#   array([[8.9498056e-04, 9.9910504e-01]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   3.712,
#   array([[0.9492226 , 0.05077739]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.776,
#   array([[0.9916259 , 0.00837412]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.84,
#   array([[0.5675207 , 0.43247938]], dtype=float32),
#   array([0])),
#  ('data/test_data/DRONE_003.wav',
#   3.904,
#   array([[0.03037982, 0.96962017]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   3.968,
#   array([[0.05217998, 0.94782   ]], dtype=float32),
#   array([1])),
#  ('data/test_data/DRONE_003.wav',
#   4.032,
#   array([[0.8949969 , 0.10500315]], dtype=float32),
#   array([0])),
#  ...]

# %%
import pandas as pd

# Create DataFrame
df = pd.DataFrame(predictions_with_metadata, columns=['Filename', 'Start_Time', 'Probabilities', 'Predictions'])

# Saving to CSV for further analysis
df.to_csv('predictions_with_timestamps.csv', index=False)
